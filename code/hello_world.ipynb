# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/michael-borck/code-python-consult-ai/blob/main/code/hello_world.ipynb)
#
# # Hello, World! - Your First Python Adventure
#
# *This is a starting point — the book walks you through building the full version step by step. Complete it as an exercise using the skills and techniques from the chapter.*
#
# *This notebook was generated from the book's project code. See the companion book for the full explanation and step-by-step development process.*

# %%
# Your first chatbot - Version 0.1
print("Hello, I'm PyBot!")
print("I'm your Python-powered digital assistant.")
print("As you learn more Python, I'll become smarter too!")
